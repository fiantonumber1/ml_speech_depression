# %%
##### Batas penggunaan model yang sudah jadi #############

# %%
import tensorflow as tf
from tensorflow.keras import models
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
from tensorflow.keras.preprocessing.image import img_to_array
import jsons
from flask import Flask, jsonify, request

# %%
def get_spectrogram_and_label_id(audio_file, label):
    spectrogram = audio_file
    spectrogram = tf.expand_dims(spectrogram, -1)
    label_id = tf.argmax(label == commands)
    return spectrogram, label_id

def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2]

def get_waveform_and_label(file_path):
    label = get_label(file_path)
    audio_binary = tf.io.read_file(file_path)
    waveform = file_path
    return waveform, label

def preprocess_dataset(files):
    files_ds = tf.data.Dataset.from_tensor_slices(files)
    output_ds = files_ds.map(get_waveform_and_label, num_parallel_calls=AUTOTUNE)
    output_ds = output_ds.map(
        get_spectrogram_and_label_id, num_parallel_calls=AUTOTUNE)
    return output_ds

def transformator(file_gambar_spectogram):
    IMG_PATH = file_gambar_spectogram
    image = cv2.imread(IMG_PATH)
    image = cv2.resize(image, (512, 512))
    image = image.astype("float") / 255.0
    image = img_to_array(image)
    image = np.expand_dims(image, axis=0)
    return image

def identifikasi_gambar(gambar):
    y_pred = np.argmax(model.predict(transformator(gambar)), axis=1)
    if str(y_pred[0]) == "0":
       label_nama = "Depresi"
    elif str(y_pred[0]) == "1":
       label_nama = "Normal"
    return label_nama

def transform_audio_to_spectogram_to_testing(audio_file):
    y, sr = librosa.load(audio_file)
    librosa.feature.melspectrogram(y=y, sr=sr)
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128,
                                               fmax=8000)
    fig, ax = plt.subplots()
    S_dB = librosa.power_to_db(S, ref=np.max)
    img = librosa.display.specshow(S_dB)
            # ax.set(title='Log Mel-frequency spectrogram')
    folder_dituju = "E:\Capstone_Project\\runningan\jalur_lewat_testing"
    savefigure = os.path.join(folder_dituju, 'jalur_lewat.jpg')
    plt.savefig(savefigure)
    status = identifikasi_gambar(savefigure)
    return status

AUTOTUNE = tf.data.AUTOTUNE

# %%
#audio_file = "E:\Capstone_Project\Depressionvsnormal\Depression\Depression4.wav"
#hasil = transform_audio_to_spectogram_to_testing(audio_file)

#print(hasil)

# %%
model_ml = "E:\Capstone_Project\heroku\\predictive_model_v_8.h5"
model = models.load_model(model_ml)

# %%
from flask import Flask
from gevent.pywsgi import WSGIServer

app = Flask(__name__)
@app.route('/predict', methods=['POST'])
def infer_image():
    if request.method == 'POST':
        if 'file' not in request.files:
            return "Masukan hanya jenis file saja"
        file = request.files.get('file')
        try:
            img = transform_audio_to_spectogram_to_testing(file)
            img_respon =  { "status_user":img,"status_running":"Sukses"}
        except:
            img_respon =  { "status_user":"-","status_running":"Gagal"}
        return img_respon
    
@app.route('/', methods=['GET'])
def index():
    return "Selamat datang dimachine learning kami"

if __name__ == '__main__':
    # Debug/Development
    # app.run(debug=True, host="0.0.0.0", port="5000")
    # Production
    http_server = WSGIServer(('127.0.0.1', 5000), app)
    http_server.serve_forever()
# Out:
# 1/1 [==============================] - 0s 212ms/step
# 127.0.0.1 - - [2022-06-03 09:15:04] "POST /predict HTTP/1.1" 200 159 0.475008
# 1/1 [==============================] - 0s 62ms/step
# 127.0.0.1 - - [2022-06-03 09:15:49] "POST /predict HTTP/1.1" 200 159 0.250987
# Traceback (most recent call last):
#   File "C:\Users\fiansyah\anaconda3\lib\site-packages\gevent\_ffi\loop.py", line 270, in python_check_callback
#     def python_check_callback(self, watcher_ptr): # pylint:disable=unused-argument
# KeyboardInterrupt
# 2022-06-03T02:16:43Z
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6700/3851902977.py in <module>
#      25     # Production
#      26     http_server = WSGIServer(('127.0.0.1', 5000), app)
# ---> 27     http_server.serve_forever()
#
# ~\anaconda3\lib\site-packages\gevent\baseserver.py in serve_forever(self, stop_timeout)
#     398             self.start()
#     399         try:
# --> 400             self._stop_event.wait()
#     401         finally:
#     402             Greenlet.spawn(self.stop, timeout=stop_timeout).join()
#
# ~\anaconda3\lib\site-packages\gevent\_gevent_cevent.cp38-win_amd64.pyd in gevent._gevent_cevent.Event.wait()
#
# ~\anaconda3\lib\site-packages\gevent\_gevent_c_abstract_linkable.cp38-win_amd64.pyd in gevent._gevent_c_abstract_linkable.AbstractLinkable._wait()
#
# ~\anaconda3\lib\site-packages\gevent\_gevent_c_abstract_linkable.cp38-win_amd64.pyd in gevent._gevent_c_abstract_linkable.AbstractLinkable._wait_core()
#
# ~\anaconda3\lib\site-packages\gevent\_gevent_c_abstract_linkable.cp38-win_amd64.pyd in gevent._gevent_c_abstract_linkable.AbstractLinkable._wait_core()
#
# ~\anaconda3\lib\site-packages\gevent\_gevent_c_abstract_linkable.cp38-win_amd64.pyd in gevent._gevent_c_abstract_linkable.AbstractLinkable._AbstractLinkable__wait_to_be_notified()
#
# ~\anaconda3\lib\site-packages\gevent\_gevent_c_abstract_linkable.cp38-win_amd64.pyd in gevent._gevent_c_abstract_linkable.AbstractLinkable._switch_to_hub()
#
# ~\anaconda3\lib\site-packages\gevent\_gevent_c_greenlet_primitives.cp38-win_amd64.pyd in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# ~\anaconda3\lib\site-packages\gevent\_gevent_c_greenlet_primitives.cp38-win_amd64.pyd in gevent._gevent_c_greenlet_primitives.SwitchOutGreenletWithLoop.switch()
#
# src/gevent/_gevent_c_greenlet_primitives.pxd in gevent._gevent_c_greenlet_primitives._greenlet_switch()
#
# ~\anaconda3\lib\site-packages\gevent\_ffi\loop.py in python_check_callback(self, watcher_ptr)
#     268
#     269     if not PYPY:
# --> 270         def python_check_callback(self, watcher_ptr): # pylint:disable=unused-argument
#     271             # If we have the onerror callback, this is a no-op; all the real
#     272             # work to rethrow the exception is done by the onerror callback
#
# KeyboardInterrupt:
