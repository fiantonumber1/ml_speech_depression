# %%
import os
import zipfile
import random
import jsons
from flask import Flask, jsonify, request
import shutil
import tensorflow as tf
import matplotlib.pyplot as plt
import mutagen
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from shutil import copyfile
from mutagen.wave import WAVE
from pydub import AudioSegment
import matplotlib.pyplot as plt
import librosa
import numpy as np
import librosa.display
import os
from tensorflow.keras import models
from flask import Flask, request
import cv2
from tensorflow.keras.preprocessing.image import img_to_array
import glob
import librosa
import numpy as np
import librosa.display
import subprocess
from os import walk
import csv
import shutil
from tensorflow.keras.layers import Embedding, Dense, LSTM, Bidirectional
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import  spectogram_only
import split_voice
# Out:
# C:\Users\fiansyah\anaconda3\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
### Warning
### Warning
### Warning
### Running for split audio and change to spectogram
def split_and_spectogram(rootdir): #rootdir is a source of folder which contain a datasheet
    ##### Make Split
    induknya_1 = "./Depressionvsnormal"
    folder_depresi='./Depressionvsnormal/Depression'
    folder_normal = "./Depressionvsnormal/Normal"
    try:
        os.mkdir(induknya_1)
    except:
        print("its exist")
    try:
        os.mkdir(folder_depresi)
    except:
        print("its exist")
    try:
        os.mkdir(folder_normal)
    except:
        print("its exist")
    loopingke = split_voice.splitvoice(rootdir,folder_depresi,folder_normal)
    
    ##### Make Spectogram
    induknya_2 = "./Depressionvsnormal_spectogram"
    try:
        os.mkdir(induknya_2)
    except:
        print("its exist")
    folder_asal_depresi = folder_depresi
    folder_dituju_depresi = ".//Depressionvsnormal_spectogram//Depression"
    try:
        os.mkdir(folder_dituju_depresi)
    except:
        print("its exist")
    spectogram_only.spectogram_only(folder_asal_depresi ,folder_dituju_depresi,"Depression")

    folder_asal_normal = folder_normal
    folder_dituju_normal = ".//Depressionvsnormal_spectogram//Normal"
    try:
        os.mkdir(folder_dituju_normal)
    except:
        print("its exist")
    spectogram_only.spectogram_only(folder_asal_normal ,folder_dituju_normal,"Normal")

# %%
split_and_spectogram('E:\\Capstone_Project\\Folder_Datasheet')  # Only use when need a spectogram datasheet
# Out:
# Split sukses ke1
# Split sukses ke2
# Split sukses ke3
# Split sukses ke4
# Split sukses ke5
# Split sukses ke6
# Split sukses ke7
# Split sukses ke8
# Split sukses ke9
# Split sukses ke10
# Split sukses ke11
# Split sukses ke12
# Split sukses ke13
# Split sukses ke14
# Split sukses ke15
# Split sukses ke16
# Split sukses ke17
# Split sukses ke18
# Split sukses ke19
# Split sukses ke20
# Split sukses ke21
# Split sukses ke22
# Split sukses ke23
# Split sukses ke24
# Split sukses ke25
# Split sukses ke26
# Split sukses ke27
# Split sukses ke28
# Split sukses ke29
# Split sukses ke30
# Split sukses ke31
# Split sukses ke32
# Split sukses ke33
# Split sukses ke34
# Split sukses ke35
# Split sukses ke36
# Split sukses ke37
# Split sukses ke38
# Split sukses ke39
# Split sukses ke40
# Split sukses ke41
# Split sukses ke42
# Split sukses ke43
# Split sukses ke44
# Split sukses ke45
# Split sukses ke46
# Split sukses ke47
# Split sukses ke48
# Split sukses ke49
# Split sukses ke50
# Split sukses ke51
# Split sukses ke52
# Split sukses ke53
# Split sukses ke54
# Split sukses ke55
# Split sukses ke56
# Split sukses ke57
# Split sukses ke58
# Split sukses ke59
# Split sukses ke60
# Split sukses ke61
# Split sukses ke62
# Split sukses ke63
# Split sukses ke64
# Split sukses ke65
# Split sukses ke66
# Split sukses ke67
# Split sukses ke68
# Split sukses ke69
# Split sukses ke70
# Split sukses ke71
# Split sukses ke72
# Split sukses ke73
# Split sukses ke74
# Split sukses ke75
# Split sukses ke76
# Split sukses ke77
# Split sukses ke78
# Split sukses ke79
# Split sukses ke80
# Split sukses ke81
# Split sukses ke82
# Split sukses ke83
# Split sukses ke84
# Split sukses ke85
# Split sukses ke86
# Split sukses ke87
# Split sukses ke88
# Split sukses ke89
# Split sukses ke90
# Split sukses ke91
# Split sukses ke92
# Split sukses ke93
# Split sukses ke94
# Split sukses ke95
# Split sukses ke96
# Split sukses ke97
# Split sukses ke98
# Split sukses ke99
# Split sukses ke100
# Split sukses ke101
# Split sukses ke102
# Split sukses ke103
# Split sukses ke104
# Split sukses ke105
# Split sukses ke106
# Split sukses ke107
# Split sukses ke108
# Split sukses ke109
# Split sukses ke110
# Split sukses ke111
# Split sukses ke112
# Split sukses ke113
# Split sukses ke114
# Split sukses ke115
# Split sukses ke116
# Split sukses ke117
# Split sukses ke118
# Split sukses ke119
# Split sukses ke120
# Split sukses ke121
# Split sukses ke122
# Split sukses ke123
# Split sukses ke124
# Split sukses ke125
# Split sukses ke126
# Split sukses ke127
# Split sukses ke128
# Split sukses ke129
# Split sukses ke130
# Split sukses ke131
# Split sukses ke132
# Split sukses ke133
# Split sukses ke134
# Split sukses ke135
# Split sukses ke136
# Split sukses ke137
# Split sukses ke138
# Split sukses ke139
# Split sukses ke140
# Split sukses ke141
# Split sukses ke142
# Split sukses ke143
# Split sukses ke144
# Split sukses ke145
# Split sukses ke146
# Split sukses ke147
# Split sukses ke148
# Split sukses ke149
# Split sukses ke150
# Split sukses ke151
# Split sukses ke152
# Split sukses ke153
# Split sukses ke154
# Split sukses ke155
# Split sukses ke156
# Split sukses ke157
# Split sukses ke158
# Split sukses ke159
# Split sukses ke160
# Split sukses ke161
# Split sukses ke162
# Split sukses ke163
# Split sukses ke164
# Split sukses ke165
# Split sukses ke166
# Split sukses ke167
# Split sukses ke168
# Split sukses ke169
# Split sukses ke170
# Split sukses ke171
# Split sukses ke172
# Split sukses ke173
# Split sukses ke174
# Split sukses ke175
# Split sukses ke176
# Split sukses ke177
# Split sukses ke178
# Split sukses ke179
# Split sukses ke180
# Split sukses ke181
# Split sukses ke182
# Split sukses ke183
# Split sukses ke184
# Split sukses ke185
# Split sukses ke186
# Split sukses ke187
# Split sukses ke188
# Split sukses ke189
# Split sukses ke190
# Split sukses ke191
# Split sukses ke192
# Split sukses ke193
# Split sukses ke194
# Split sukses ke195
# Split sukses ke196
# Split sukses ke197
# Split sukses ke198
# Split sukses ke199
# Split sukses ke200
# Split sukses ke201
# Split sukses ke202
# Split sukses ke203
# Split sukses ke204
# Split sukses ke205
# Split sukses ke206
# Split sukses ke207
# Split sukses ke208
# Split sukses ke209
# Split sukses ke210
# Split sukses ke211
# Split sukses ke212
# Split sukses ke213
# Split sukses ke214
# Split sukses ke215
# Split sukses ke216
# Split sukses ke217
# Split sukses ke218
# Split sukses ke219
# Split sukses ke220
# Split sukses ke221
# Split sukses ke222
# Split sukses ke223
# Split sukses ke224
# Split sukses ke225
# Split sukses ke226
# Split sukses ke227
# Split sukses ke228
# Split sukses ke229
# Split sukses ke230
# Split sukses ke231
# Split sukses ke232
# Split sukses ke233
# Split sukses ke234
# Split sukses ke235
# Split sukses ke236
# Split sukses ke237
# Split sukses ke238
# Split sukses ke239
# Split sukses ke240
# Split sukses ke241
# Split sukses ke242
# Split sukses ke243
# Split sukses ke244
# Split sukses ke245
# Split sukses ke246
# Split sukses ke247
# Split sukses ke248
# Split sukses ke249
# Split sukses ke250
# Split sukses ke251
# Split sukses ke252
# Split sukses ke253
# Split sukses ke254
# Split sukses ke255
# Split sukses ke256
# Split sukses ke257
# Split sukses ke258
# Split sukses ke259
# Split sukses ke260
# Split sukses ke261
# Split sukses ke262
# Split sukses ke263
# Split sukses ke264
# Split sukses ke265
# Split sukses ke266
# Split sukses ke267
# Split sukses ke268
# Split sukses ke269
# Split sukses ke270
# Split sukses ke271
# Split sukses ke272
# Split sukses ke273
# Split sukses ke274
# Split sukses ke275
# Split sukses ke276
# Split sukses ke277
# Split sukses ke278
# Split sukses ke279
# Split sukses ke280
# Split sukses ke281
# Split sukses ke282
# Split sukses ke283
# Split sukses ke284
# Split sukses ke285
# Split sukses ke286
# Split sukses ke287
# Split sukses ke288
# Split sukses ke289
# Split sukses ke290
# Split sukses ke291
# Split sukses ke292
# Split sukses ke293
# Split sukses ke294
# Split sukses ke295
# Split sukses ke296
# Split sukses ke297
# Split sukses ke298
# Split sukses ke299
# Split sukses ke300
# Split sukses ke301
# Split sukses ke302
# Split sukses ke303
# Split sukses ke304
# Split sukses ke305
# Split sukses ke306
# Split sukses ke307
# Split sukses ke308
# Split sukses ke309
# Split sukses ke310
# Split sukses ke311
# Split sukses ke312
# Split sukses ke313
# Split sukses ke314
# Split sukses ke315
# Split sukses ke316
# Split sukses ke317
# Split sukses ke318
# Split sukses ke319
# Split sukses ke320
# Split sukses ke321
# Split sukses ke322
# Split sukses ke323
# Split sukses ke324
# Split sukses ke325
# Split sukses ke326
# Split sukses ke327
# Split sukses ke328
# Split sukses ke329
# Split sukses ke330
# Split sukses ke331
# Split sukses ke332
# Split sukses ke333
# Split sukses ke334
# Split sukses ke335
# Split sukses ke336
# Split sukses ke337
# Split sukses ke338
# Split sukses ke339
# Split sukses ke340
# Split sukses ke341
# Split sukses ke342
# Split sukses ke343
# Split sukses ke344
# Split sukses ke345
# Split sukses ke346
# Split sukses ke347
# Split sukses ke348
# Split sukses ke349
# Split sukses ke350
# Split sukses ke351
# Split sukses ke352
# Split sukses ke353
# Split sukses ke354
# Split sukses ke355
# Split sukses ke356
# Split sukses ke357
# Split sukses ke358
# Split sukses ke359
# Split gagal ke1
# Split sukses ke360
# Split sukses ke361
# Split gagal ke2
# Split sukses ke362
# Split sukses ke363
# Split sukses ke364
# Split gagal ke3
# Split sukses ke365
# Split sukses ke366
# Split sukses ke367
# Split sukses ke368
# Split sukses ke369
# Split sukses ke370
# Split sukses ke371
# Split sukses ke372
# Split sukses ke373
# Split sukses ke374
# Split sukses ke375
# Split sukses ke376
# Split sukses ke377
# Split sukses ke378
# Split sukses ke379
# Split sukses ke380
# Split gagal ke4
# Split sukses ke381
# Split sukses ke382
# Split sukses ke383
# Split gagal ke5
# Split sukses ke384
# Split sukses ke385
# Split sukses ke386
# Split sukses ke387
# Split gagal ke6
# Split sukses ke388
# Split sukses ke389
# Split sukses ke390
# Split gagal ke7
# Split sukses ke391
# Split sukses ke392
# Split sukses ke393
# Split sukses ke394
# Split sukses ke395
# Split sukses ke396
# Split sukses ke397
# Split sukses ke398
# Split sukses ke399
# Split sukses ke400
# Split sukses ke401
# Split sukses ke402
# Split sukses ke403
# Split sukses ke404
# Split sukses ke405
# Split sukses ke406
# Split sukses ke407
# Split sukses ke408
# Split sukses ke409
# Split sukses ke410
# Split sukses ke411
# Split gagal ke8
# Split sukses ke412
# Split sukses ke413
# Split sukses ke414
# Split sukses ke415
# Split sukses ke416
# Split sukses ke417
# Split sukses ke418
# Split sukses ke419
# Split sukses ke420
# Split sukses ke421
# Split sukses ke422
# Split sukses ke423
# Split sukses ke424
# Split sukses ke425
# Split sukses ke426
# Split sukses ke427
# Split sukses ke428
# Split sukses ke429
# Split sukses ke430
# Split sukses ke431
# Split sukses ke432
# Split sukses ke433
# Split sukses ke434
# Split sukses ke435
# Split gagal ke9
# Split sukses ke436
# Split sukses ke437
# Split sukses ke438
# Split sukses ke439
# Split sukses ke440
# Split sukses ke441
# Split gagal ke10
# Split sukses ke442
# Split sukses ke443
# Split sukses ke444
# Split sukses ke445
# Split sukses ke446
# Split sukses ke447
# Split sukses ke448
# Split sukses ke449
# Split sukses ke450
# Split sukses ke451
# Split sukses ke452
# Split sukses ke453
# Split sukses ke454
# Split sukses ke455
# Split sukses ke456
# Split sukses ke457
# Split sukses ke458
# Split sukses ke459
# Split sukses ke460
# Split sukses ke461
# Split sukses ke462
# Split sukses ke463
# Split sukses ke464
# Split sukses ke465
# Split sukses ke466
# Split sukses ke467
# Split sukses ke468
# Split sukses ke469
# Split gagal ke11
# Split sukses ke470
# Split sukses ke471
# Split sukses ke472
# Split gagal ke12
# Split sukses ke473
# Split sukses ke474
# Split sukses ke475
# Split sukses ke476
# Split sukses ke477
# Split sukses ke478
# Split sukses ke479
# Split sukses ke480
# Split sukses ke481
# Split sukses ke482
# Split sukses ke483
# Split sukses ke484
# Split sukses ke485
# Split sukses ke486
# Split sukses ke487
# Split sukses ke488
# Split sukses ke489
# Split gagal ke13
# Split sukses ke490
# Split sukses ke491
# Split sukses ke492
# Split gagal ke14
# Split gagal ke15
# Split sukses ke493
# Split sukses ke494
# Split gagal ke16
# Split sukses ke495
# Split sukses ke496
# Split gagal ke17
# Split sukses ke497
# Split sukses ke498
# Split sukses ke499
# Split sukses ke500
# Split sukses ke501
# Split sukses ke502
# Split sukses ke503
# Split sukses ke504
# Split sukses ke505
# Split gagal ke18
# Split sukses ke506
# Split sukses ke507
# Split sukses ke508
# Split sukses ke509
# Split sukses ke510
# Split sukses ke511
# Split sukses ke512
# Split sukses ke513
# Split sukses ke514
# Split sukses ke515
# Split sukses ke516
# Split sukses ke517
# Split sukses ke518
# Split sukses ke519
# Split sukses ke520
# Split gagal ke19
# Split gagal ke20
# Split sukses ke521
# Split sukses ke522
# Split sukses ke523
# Split sukses ke524
# Split sukses ke525
# Split sukses ke526
# Split sukses ke527
# Split sukses ke528
# Split sukses ke529
# Split sukses ke530
# Split sukses ke531
# Split sukses ke532
# Split sukses ke533
# Split sukses ke534
# Split sukses ke535
# Split sukses ke536
# Split sukses ke537
# Split sukses ke538
# Split sukses ke539
# Split sukses ke540
# Split sukses ke541
# Split sukses ke542
# Split sukses ke543
# Split sukses ke544
# Split sukses ke545
# Split sukses ke546
# Split sukses ke547
# Split sukses ke548
# Split sukses ke549
# Split sukses ke550
# Split sukses ke551
# Split sukses ke552
# Split sukses ke553
# Split sukses ke554
# Split sukses ke555
# Split sukses ke556
# Split sukses ke557
# Split sukses ke558
# Split sukses ke559
# Split sukses ke560
# Split sukses ke561
# Split sukses ke562
# Split sukses ke563
# Split sukses ke564
# Split sukses ke565
# Split sukses ke566
# Split sukses ke567
# Split sukses ke568
# Split sukses ke569
# Split sukses ke570
# Split sukses ke571
# Split sukses ke572
# Split sukses ke573
# Split sukses ke574
# Split sukses ke575
# Split sukses ke576
# Split sukses ke577
# Split sukses ke578
# Split sukses ke579
# Split sukses ke580
# Split sukses ke581
# Split sukses ke582
# Split sukses ke583
# Split sukses ke584
# Split sukses ke585
# Split sukses ke586
# Split sukses ke587
# Split sukses ke588
# Split sukses ke589
# Split sukses ke590
# Split sukses ke591
# Split sukses ke592
# Split sukses ke593
# Split sukses ke594
# Split sukses ke595
# Split sukses ke596
# Split sukses ke597
# Split sukses ke598
# Split sukses ke599
# Split sukses ke600
# Split sukses ke601
# Split sukses ke602
# Split sukses ke603
# Split sukses ke604
# Split sukses ke605
# Split sukses ke606
# Split sukses ke607
# Split sukses ke608
# Split sukses ke609
# Split sukses ke610
# Split sukses ke611
# Split sukses ke612
# Split sukses ke613
# Split sukses ke614
# Split sukses ke615
# Split sukses ke616
# Split sukses ke617
# Split sukses ke618
# Split sukses ke619
# Split sukses ke620
# Split sukses ke621
# Split sukses ke622
# Split sukses ke623
# Split sukses ke624
# Split sukses ke625
# Split sukses ke626
# Split sukses ke627
# Split sukses ke628
# Split sukses ke629
# Split sukses ke630
# Split sukses ke631
# Split sukses ke632
# Split sukses ke633
# Split sukses ke634
# Split sukses ke635
# Split sukses ke636
# Split sukses ke637
# Split sukses ke638
# Split sukses ke639
# Split sukses ke640
# Split sukses ke641
# Split sukses ke642
# Split sukses ke643
# Split sukses ke644
# Split sukses ke645
# Split sukses ke646
# Split sukses ke647
# Split sukses ke648
# Split sukses ke649
# Split sukses ke650
# Split sukses ke651
# Split sukses ke652
# Split sukses ke653
# Split sukses ke654
# Split sukses ke655
# Split sukses ke656
# Split sukses ke657
# Split sukses ke658
# Split sukses ke659
# Split sukses ke660
# Split sukses ke661
# Split sukses ke662
# Split sukses ke663
# Split sukses ke664
# Split sukses ke665
# Split sukses ke666
# Split sukses ke667
# Split sukses ke668
# Split sukses ke669
# Split sukses ke670
# Split sukses ke671
# Split sukses ke672
# Split sukses ke673
# Split sukses ke674
# Split sukses ke675
# Split sukses ke676
# Split sukses ke677
# Split sukses ke678
# Split sukses ke679
# Split sukses ke680
# Split sukses ke681
# Split sukses ke682
# Split sukses ke683
# Split sukses ke684
# Split sukses ke685
# Split sukses ke686
# Split sukses ke687
# Split sukses ke688
# Split sukses ke689
# Split sukses ke690
# Split sukses ke691
# Split sukses ke692
# Split sukses ke693
# Split sukses ke694
# Split sukses ke695
# Split sukses ke696
# Split sukses ke697
# Split sukses ke698
# Split sukses ke699
# Split sukses ke700
# Split sukses ke701
# Split sukses ke702
# Split sukses ke703
# Split sukses ke704
# Split sukses ke705
# Split sukses ke706
# Split sukses ke707
# Split sukses ke708
# Split sukses ke709
# Split sukses ke710
# Split sukses ke711
# Split sukses ke712
# Split sukses ke713
# Split sukses ke714
# Split gagal ke21
# Split sukses ke715
# Split sukses ke716
# Split sukses ke717
# Split sukses ke718
# Split sukses ke719
# Split sukses ke720
# Split sukses ke721
# Split gagal ke22
# Split sukses ke722
# Split sukses ke723
# Split sukses ke724
# Split sukses ke725
# Split sukses ke726
# Split sukses ke727
# Split sukses ke728
# Split gagal ke23
# Split sukses ke729
# Split gagal ke24
# Split sukses ke730
# Split sukses ke731
# Split sukses ke732
# Split sukses ke733
# Split sukses ke734
# Split gagal ke25
# Split sukses ke735
# Split sukses ke736
# Split sukses ke737
# Split sukses ke738
# Split sukses ke739
# Split gagal ke26
# Split sukses ke740
# Split sukses ke741
# Split gagal ke27
# Split sukses ke742
# Split gagal ke28
# Split sukses ke743
# Split sukses ke744
# Split sukses ke745
# Split gagal ke29
# Split gagal ke30
# Split sukses ke746
# Split sukses ke747
# Split sukses ke748
# Split sukses ke749
# Split sukses ke750
# Split gagal ke31
# Split sukses ke751
# Split sukses ke752
# Split sukses ke753
# Split sukses ke754
# Split sukses ke755
# Split sukses ke756
# Split sukses ke757
# Split gagal ke32
# Split gagal ke33
# Split sukses ke758
# Split gagal ke34
# Split sukses ke759
# Split sukses ke760
# Split gagal ke35
# Split sukses ke761
# Split gagal ke36
# Split sukses ke762
# Split gagal ke37
# Split sukses ke763
# Split sukses ke764
# Split sukses ke765
# Split sukses ke766
# Split sukses ke767
# Split sukses ke768
# Split sukses ke769
# Split sukses ke770
# Split sukses ke771
# Split sukses ke772
# Split sukses ke773
# Split gagal ke38
# Split gagal ke39
# Split sukses ke774
# Split sukses ke775
# Split gagal ke40
# Split sukses ke776
# Split sukses ke777
# Split gagal ke41
# Split sukses ke778
# Split sukses ke779
# Split sukses ke780
# Split sukses ke781
# Split sukses ke782
# Split sukses ke783
# Split sukses ke784
# Split sukses ke785
# Split sukses ke786
# Split sukses ke787
# Split sukses ke788
# Split gagal ke42
# Split sukses ke789
# Split sukses ke790
# Split sukses ke791
# Split sukses ke792
# Split sukses ke793
# Split gagal ke43
# Split sukses ke794
# Split sukses ke795
# Split sukses ke796
# Split sukses ke797
# Split gagal ke44
# Split sukses ke798
# Split sukses ke799
# Split sukses ke800
# Split sukses ke801
# Split gagal ke45
# Split sukses ke802
# Split gagal ke46
# Split sukses ke803
# Split sukses ke804
# Split sukses ke805
# Split sukses ke806
# Split sukses ke807
# Split sukses ke808
# Split sukses ke809
# Split sukses ke810
# Split gagal ke47
# Split gagal ke48
# Split sukses ke811
# Split sukses ke812
# Split sukses ke813
# Split sukses ke814
# Split sukses ke815
# Split sukses ke816
# Split sukses ke817
# Split sukses ke818
# Split sukses ke819
# Split sukses ke820
# Split sukses ke821
# Split sukses ke822
# Split sukses ke823
# Split sukses ke824
# Split sukses ke825
# Split sukses ke826
# Split sukses ke827
# Split sukses ke828
# Split sukses ke829
# Split sukses ke830
# Split sukses ke831
# Split sukses ke832
# Split gagal ke49
# Split sukses ke833
# Split sukses ke834
# Split sukses ke835
# Split sukses ke836
# Split sukses ke837
# Split sukses ke838
# Split sukses ke839
# Split sukses ke840
# Split sukses ke841
# Split gagal ke50
# Split gagal ke51
# Split sukses ke842
# Split sukses ke843
# Split sukses ke844
# Split sukses ke845
# Split gagal ke52
# Split sukses ke846
# Split sukses ke847
# Split sukses ke848
# Split sukses ke849
# Split sukses ke850
# Split gagal ke53
# Split gagal ke54
# Split gagal ke55
# Split sukses ke851
# Split sukses ke852
# Split sukses ke853
# Split sukses ke854
# Split gagal ke56
# Split sukses ke855
# Split gagal ke57
# Split gagal ke58
# Split gagal ke59
# Split sukses ke856
# Split sukses ke857
# Split sukses ke858
# Split sukses ke859
# Split gagal ke60
# Split sukses ke860
# Split sukses ke861
# Split sukses ke862
# Split gagal ke61
# Split sukses ke863
# Split sukses ke864
# Split gagal ke62
# Split sukses ke865
# Split sukses ke866
# Split sukses ke867
# Split gagal ke63
# Split gagal ke64
# Split sukses ke868
# Split sukses ke869
# Split sukses ke870
# Split sukses ke871
# Split sukses ke872
# Split sukses ke873
# Split sukses ke874
# Split sukses ke875
# Split sukses ke876
# Split sukses ke877
# Split sukses ke878
# Split sukses ke879
# Split sukses ke880
# Split sukses ke881
# Split sukses ke882
# Split sukses ke883
# Split sukses ke884
# Split sukses ke885
# Split sukses ke886
# Split sukses ke887
# Split sukses ke888
# Split sukses ke889
# Split sukses ke890
# Split sukses ke891
# Split sukses ke892
# Split sukses ke893
# Split sukses ke894
# Split sukses ke895
# Split sukses ke896
# Split sukses ke897
# Split sukses ke898
# Split sukses ke899
# Split sukses ke900
# Split sukses ke901
# Split sukses ke902
# Split sukses ke903
# Split sukses ke904
# Split sukses ke905
# Split sukses ke906
# Split sukses ke907
# Split sukses ke908
# Split sukses ke909
# Split sukses ke910
# Split sukses ke911
# Split sukses ke912
# Split sukses ke913
# Split sukses ke914
# Split sukses ke915
# Split sukses ke916
# Split sukses ke917
# Split sukses ke918
# Split sukses ke919
# Split sukses ke920
# Split sukses ke921
# Split sukses ke922
# Split sukses ke923
# Split sukses ke924
# Split sukses ke925
# Split sukses ke926
# Split sukses ke927
# Split sukses ke928
# Split sukses ke929
# Split sukses ke930
# Split sukses ke931
# Split sukses ke932
# Split sukses ke933
# Split sukses ke934
# Split sukses ke935
# Split sukses ke936
# Split sukses ke937
# Split sukses ke938
# Split sukses ke939
# Split sukses ke940
# Split sukses ke941
# Split sukses ke942
# Split sukses ke943
# Split sukses ke944
# Split sukses ke945
# Split sukses ke946
# Split sukses ke947
# Split sukses ke948
# Split sukses ke949
# Split sukses ke950
# Split sukses ke951
# Split sukses ke952
# Split sukses ke953
# Split sukses ke954
# Split sukses ke955
# Split sukses ke956
# Split sukses ke957
# Split sukses ke958
# Split sukses ke959
# Split sukses ke960
# Split sukses ke961
# Split sukses ke962
# Split sukses ke963
# Split sukses ke964
# Split sukses ke965
# Split sukses ke966
# Split sukses ke967
# Split sukses ke968
# Split sukses ke969
# Split sukses ke970
# Split sukses ke971
# Split sukses ke972
# Split sukses ke973
# Split sukses ke974
# Split sukses ke975
# Split sukses ke976
# Split sukses ke977
# Split sukses ke978
# Split sukses ke979
# Split sukses ke980
# Split sukses ke981
# Split sukses ke982
# Split sukses ke983
# Split sukses ke984
# Split sukses ke985
# Split sukses ke986
# Split sukses ke987
# Split sukses ke988
# Split sukses ke989
# Split sukses ke990
# Split sukses ke991
# Split sukses ke992
# Split sukses ke993
# Split sukses ke994
# Split sukses ke995
# Split sukses ke996
# Split sukses ke997
# Split sukses ke998
# Split sukses ke999
# Split sukses ke1000
# Split sukses ke1001
# Split sukses ke1002
# Split sukses ke1003
# Split sukses ke1004
# Split sukses ke1005
# Split sukses ke1006
# Split sukses ke1007
# Split sukses ke1008
# Split sukses ke1009
# Split sukses ke1010
# Split sukses ke1011
# Split sukses ke1012
# Split sukses ke1013
# Split sukses ke1014
# Split sukses ke1015
# Split sukses ke1016
# Split sukses ke1017
# Split sukses ke1018
# Split sukses ke1019
# Split sukses ke1020
# Split sukses ke1021
# Split sukses ke1022
# Split sukses ke1023
# Split sukses ke1024
# Split sukses ke1025
# Split sukses ke1026
# Split sukses ke1027
# Split sukses ke1028
# Split sukses ke1029
# Split sukses ke1030
# Split sukses ke1031
# Split sukses ke1032
# Split sukses ke1033
# Split sukses ke1034
# Split sukses ke1035
# Split sukses ke1036
# Split sukses ke1037
# Split sukses ke1038
# Split sukses ke1039
# Split sukses ke1040
# Split sukses ke1041
# Split sukses ke1042
# Split sukses ke1043
# Split sukses ke1044
# Split sukses ke1045
# Split sukses ke1046
# Split sukses ke1047
# Split sukses ke1048
# Split sukses ke1049
# Split sukses ke1050
# Split sukses ke1051
# Split sukses ke1052
# Split sukses ke1053
# Split sukses ke2009
# Split sukses ke2010
# Split gagal ke80
# Split sukses ke2011
# Split sukses ke2012
# Split sukses ke2013
# Split sukses ke2014
# Split sukses ke2015
# Split sukses ke2016
# Split sukses ke2017
# Split sukses ke2018
# Split sukses ke2019
# Split sukses ke2020
# Split sukses ke2021
# Split sukses ke2022
# Split sukses ke2023
# Split sukses ke2024
# Split sukses ke2025
# Split sukses ke2026
# Split sukses ke2027
# Split sukses ke2028
# Split sukses ke2029
# Split sukses ke2030
# Split sukses ke2031
# Split sukses ke2032
# Split sukses ke2033
# Split sukses ke2034
# Split sukses ke2035
# Split sukses ke2036
# Split sukses ke2037
# Split sukses ke2038
# Split sukses ke2039
# Split sukses ke2040
# Split sukses ke2041
# Split sukses ke2042
# Split sukses ke2043
# Split sukses ke2044
# Split sukses ke2045
# Split sukses ke2046
# Split sukses ke2047
# Split sukses ke2048
# Split sukses ke2049
# Split sukses ke2050
# Split sukses ke2051
# Split sukses ke2052
# Split sukses ke2053
# Split sukses ke2054
# Split sukses ke2055
# Split sukses ke2056
# Split sukses ke2057
# Split sukses ke2058
# Split sukses ke2059
# Split sukses ke2060
# Split sukses ke2061
# Split sukses ke2062
# Split sukses ke2063
# Split sukses ke2064
# Split sukses ke2065
# Split sukses ke2066
# Split sukses ke2067
# Split sukses ke2068
# Split sukses ke2069
# Split sukses ke2070
# Split sukses ke2071
# Split sukses ke2072
# Split sukses ke2073
# Split sukses ke2074
# Split sukses ke2075
# Split sukses ke2076
# Split sukses ke2077
# Split sukses ke2078
# Split sukses ke2079
# Split sukses ke2080
# Split sukses ke2081
# Split sukses ke2082
# Split sukses ke2083
# Split gagal ke81
# Split sukses ke2084
# Split sukses ke2085
# Split sukses ke2086
# Split sukses ke2087
# Split sukses ke2088
# Split sukses ke2089
# Split sukses ke2090
# Split sukses ke2091
# Split sukses ke2092
# Split sukses ke2093
# Split sukses ke2094
# Split sukses ke2095
# Split sukses ke2096
# Split sukses ke2097
# Split sukses ke2098
# Split sukses ke2099
# Split sukses ke2100
# Split sukses ke2101
# Split sukses ke2102
# Split sukses ke2103
# Split sukses ke2104
# Split sukses ke2105
# Split sukses ke2106
# Split sukses ke2107
# Split sukses ke2108
# Split sukses ke2109
# Split sukses ke2110
# Split sukses ke2111
# Split sukses ke2112
# Split sukses ke2113
# Split sukses ke2114
# Split sukses ke2115
# Split gagal ke82
# Split sukses ke2116
# Split sukses ke2117
# Split sukses ke2118
# Split sukses ke2119
# Split sukses ke2120
# Split sukses ke2121
# Split sukses ke2122
# Split sukses ke2123
# Split sukses ke2124
# Split sukses ke2125
# Split sukses ke2126
# Split sukses ke2127
# Split sukses ke2128
# Split sukses ke2129
# Split sukses ke2130
# Split sukses ke2131
# Split sukses ke2132
# Split sukses ke2133
# Split sukses ke2134
# Split sukses ke2135
# Split sukses ke2136
# Split sukses ke2137
# Split sukses ke2138
# Split sukses ke2139
# Split sukses ke2140
# Split sukses ke2141
# Split sukses ke2142
# Split sukses ke2143
# Split sukses ke2144
# Split sukses ke2145
# Split sukses ke2146
# Split sukses ke2147
# Split gagal ke83
# Split sukses ke2148
# Split sukses ke2149
# Split sukses ke2150
# Split sukses ke2151
# Split sukses ke2152
# Split sukses ke2153
# Split sukses ke2154
# Split sukses ke2155
# Split sukses ke2156
# Split sukses ke2157
# Split sukses ke2158
# Split sukses ke2159
# Split sukses ke2160
# Split sukses ke2161
# Split sukses ke2162
# Split sukses ke2163
# Split sukses ke2164
# Split sukses ke2165
# Split sukses ke2166
# Split sukses ke2167
# Split sukses ke2168
# Split sukses ke2169
# Split sukses ke2170
# Split sukses ke2171
# Split sukses ke2172
# Split sukses ke2173
# Split sukses ke2174
# Split sukses ke2175
# Split sukses ke2176
# Split sukses ke2177
# Split sukses ke2178
# Split sukses ke2179
# Split sukses ke2180
# Split sukses ke2181
# Split sukses ke2182
# Split sukses ke2183
# Split sukses ke2184
# Split sukses ke2185
# Split gagal ke84
# Split sukses ke2186
# Split sukses ke2187
# Split sukses ke2188
# Split sukses ke2189
# Split sukses ke2190
# Split sukses ke2191
# Split sukses ke2192
# Split sukses ke2193
# Split sukses ke2194
# Split sukses ke2195
# Split sukses ke2196
# Split sukses ke2197
# Split sukses ke2198
# Split sukses ke2199
# Split sukses ke2200
# Split sukses ke2201
# Split sukses ke2202
# Split sukses ke2203
# Split sukses ke2204
# Split sukses ke2205
# Split sukses ke2206
# Split sukses ke2207
# Split sukses ke2208
# Split sukses ke2209
# Split sukses ke2210
# Split sukses ke2211
# Split gagal ke85
# Split sukses ke2212
# Split sukses ke2213
# Split sukses ke2214
# Split sukses ke2215
# Split sukses ke2216
# Split sukses ke2217
# Split sukses ke2218
# Split sukses ke2219
# Split sukses ke2220
# Split sukses ke2221
# Split sukses ke2222
# Split sukses ke2223
# Split sukses ke2224
# Split sukses ke2225
# Split sukses ke2226
# Split gagal ke86
# Split sukses ke2227
# Split sukses ke2228
# Split sukses ke2229
# Split sukses ke2230
# Split sukses ke2231
# Split sukses ke2232
# Split sukses ke2233
# Split sukses ke2234
# Split sukses ke2235
# Split sukses ke2236
# Split sukses ke2237
# Split sukses ke2238
# Split sukses ke2239
# Split sukses ke2240
# Split sukses ke2241
# Split sukses ke2242
# Split sukses ke2243
# Split sukses ke2244
# Split sukses ke2245
# Split sukses ke2246
# Split sukses ke2247
# Split sukses ke2248
# Split sukses ke2249
# Split sukses ke2250
# Split sukses ke2251
# Split sukses ke2252
# Split sukses ke2253
# Split sukses ke2254
# Split sukses ke2255
# Split sukses ke2256
# Split sukses ke2257
# Split sukses ke2258
# Split sukses ke2259
# Split sukses ke2260
# Split sukses ke2261
# Split sukses ke2262
# Split sukses ke2263
# Split sukses ke2264
# Split sukses ke2265
# Split sukses ke2266
# Split gagal ke87
# Split gagal ke88
# Split sukses ke2267
# Split sukses ke2268
# Split sukses ke2269
# Split sukses ke2270
# Split sukses ke2271
# Split sukses ke2272
# Split sukses ke2273
# Split sukses ke2274
# Split sukses ke2275
# Split gagal ke89
# Split sukses ke2276
# Split sukses ke2277
# Split sukses ke2278
# Split gagal ke90
# Split sukses ke2279
# Split sukses ke2280
# Split sukses ke2281
# Split sukses ke2282
# Split sukses ke2283
# Split sukses ke2284
# Split sukses ke2285
# Split sukses ke2286
# Split sukses ke2287
# Split sukses ke2288
# Split sukses ke2289
# Split sukses ke2290
# Split sukses ke2291
# Split sukses ke2292
# Split gagal ke91
# Split sukses ke2293
# Split sukses ke2294
# Split gagal ke92
# Split sukses ke2295
# Split sukses ke2296
# Split sukses ke2297
# Split sukses ke2298
# Split sukses ke2299
# Split sukses ke2300
# Split sukses ke2301
# Split sukses ke2302
# Split sukses ke2303
# Split sukses ke2304
# Split sukses ke2305
# Split sukses ke2306
# Split sukses ke2307
# Split sukses ke2308
# Split sukses ke2309
# Split sukses ke2310
# Split sukses ke2311
# Split sukses ke2312
# Split sukses ke2313
# Split gagal ke93
# Split sukses ke2314
# Split sukses ke2315
# Split gagal ke94
# Split sukses ke2316
# Split sukses ke2317
# Split sukses ke2318
# Split sukses ke2319
# Split gagal ke95
# Split sukses ke2320
# Split sukses ke2321
# Split sukses ke2322
# Split sukses ke2323
# Split sukses ke2324
# Split sukses ke2325
# Split sukses ke2326
# Split sukses ke2327
# Split sukses ke2328
# Split sukses ke2329
# Split sukses ke2330
# Split sukses ke2331
# Split sukses ke2332
# Split sukses ke2333
# Split sukses ke2334
# Split sukses ke2335
# Split sukses ke2336
# Split sukses ke2337
# Split sukses ke2338
# Split sukses ke2339
# Split sukses ke2340
# Split sukses ke2341
# Split sukses ke2342
# Split sukses ke2343
# Split gagal ke96
# Split sukses ke2344
# Split sukses ke2345
# Split sukses ke2346
# Split sukses ke2347
# Split sukses ke2348
# Split sukses ke2349
# Split sukses ke2350
# Split sukses ke2351
# Split gagal ke97
# Split sukses ke2352
# Split sukses ke2353
# Split sukses ke2354
# Split sukses ke2355
# Split sukses ke2356
# Split sukses ke2357
# Split gagal ke98
# Split sukses ke2358
# Split sukses ke2359
# Split sukses ke2360
# Split sukses ke2361
# Split sukses ke2362
# Split sukses ke2363
# Split sukses ke2364
# Split sukses ke2365
# Split sukses ke2366
# Split sukses ke2367
# Split sukses ke2368
# Split sukses ke2369
# Split sukses ke2370
# Split sukses ke2371
# Split sukses ke2372
# ...
# Spectogram sukses ke2647
# Spectogram sukses ke2648
# Spectogram sukses ke2649
# Spectogram sukses ke2650
# Spectogram sukses ke2651
# Spectogram sukses ke2652
# Spectogram sukses ke2653
# Spectogram sukses ke2654
# Spectogram sukses ke2655
# Spectogram sukses ke2656
# Spectogram sukses ke2657
# Spectogram sukses ke2658
# Spectogram sukses ke2659
# Spectogram sukses ke2660
# Spectogram sukses ke2661
# Spectogram sukses ke2662
# Spectogram sukses ke2663
# Spectogram sukses ke2664
# Spectogram sukses ke2665
# Spectogram gagal ke2120
# Spectogram sukses ke2666
# Spectogram sukses ke2667
# Spectogram sukses ke2668
# Spectogram sukses ke2669
# Spectogram sukses ke2670
# Spectogram sukses ke2671
# Spectogram sukses ke2672
# Spectogram sukses ke2673
# Spectogram sukses ke2674
# Spectogram sukses ke2675
# Spectogram sukses ke2676
# Spectogram sukses ke2677
# Spectogram sukses ke2678
# Spectogram sukses ke2679
# Spectogram sukses ke2680
# Spectogram sukses ke2681
# Spectogram sukses ke2682
# Spectogram sukses ke2683
# Spectogram sukses ke2684
# Spectogram gagal ke2121
# Spectogram sukses ke2685
# Spectogram sukses ke2686
# Spectogram sukses ke2687
# Spectogram sukses ke2688
# Spectogram sukses ke2689
# Spectogram sukses ke2690
# Spectogram sukses ke2691
# Spectogram sukses ke2692
# Spectogram sukses ke2693
# Spectogram sukses ke2694
# Spectogram sukses ke2695
# Spectogram sukses ke2696
# Spectogram sukses ke2697
# Spectogram sukses ke2698
# Spectogram sukses ke2699
# Spectogram sukses ke2700
# Spectogram sukses ke2701
# Spectogram sukses ke2702
# Spectogram sukses ke2703
# Spectogram sukses ke2704
# Spectogram sukses ke2705
# Spectogram sukses ke2706
# Spectogram sukses ke2707
# Spectogram sukses ke2708
# Spectogram sukses ke2709
# Spectogram sukses ke2710
# Spectogram sukses ke2711
# Spectogram sukses ke2712
# Spectogram sukses ke2713
# Spectogram gagal ke2122
# Spectogram sukses ke2714
# Spectogram sukses ke2715
# Spectogram sukses ke2716
# Spectogram sukses ke2717
# Spectogram sukses ke2718
# Spectogram sukses ke2719
# Spectogram sukses ke2720
# Spectogram sukses ke2721
# Spectogram sukses ke2722
# Spectogram sukses ke2723
# Spectogram sukses ke2724
# Spectogram sukses ke2725
# Spectogram sukses ke2726
# Spectogram sukses ke2727
# Spectogram sukses ke2728
# Spectogram sukses ke2729
# Spectogram sukses ke2730
# Spectogram sukses ke2731
# Spectogram sukses ke2732
# Spectogram sukses ke2733
# Spectogram sukses ke2734
# Spectogram sukses ke2735
# Spectogram sukses ke2736
# Spectogram sukses ke2737
# Spectogram sukses ke2738
# Spectogram sukses ke2739
# Spectogram sukses ke2740
# Spectogram sukses ke2741
# Spectogram sukses ke2742
# Spectogram sukses ke2743
# Spectogram sukses ke2744
# Spectogram sukses ke2745
# Spectogram sukses ke2746
# Spectogram sukses ke2747
# Spectogram sukses ke2748
# Spectogram sukses ke2749
# Spectogram sukses ke2750
# Spectogram sukses ke2751
# Spectogram sukses ke2752
# Spectogram sukses ke2753
# Spectogram sukses ke2754
# Spectogram sukses ke2755
# Spectogram sukses ke2756
# Spectogram sukses ke2757
# Spectogram sukses ke2758
# Spectogram sukses ke2759
# Spectogram sukses ke2760
# Spectogram sukses ke2761
# Spectogram sukses ke2762
# Spectogram sukses ke2763
# Spectogram sukses ke2764
# Spectogram sukses ke2765
# Spectogram sukses ke2766
# Spectogram gagal ke2123
# Spectogram sukses ke2767
# Spectogram sukses ke2768
# Spectogram sukses ke2769
# Spectogram sukses ke2770
# Spectogram sukses ke2771
# Spectogram gagal ke2124
# Spectogram sukses ke2772
# Spectogram sukses ke2773
# Spectogram sukses ke2774
# Spectogram sukses ke2775
# Spectogram sukses ke2776
# Spectogram sukses ke2777
# Spectogram sukses ke2778
# Spectogram sukses ke2779
# Spectogram sukses ke2780
# Spectogram sukses ke2781
# Spectogram sukses ke2782
# Spectogram sukses ke2783
# Spectogram sukses ke2784
# Spectogram sukses ke2785
# Spectogram sukses ke2786
# Spectogram gagal ke2125
# Spectogram sukses ke2787
# Spectogram sukses ke2788
# Spectogram sukses ke2789
# Spectogram sukses ke2790
# Spectogram sukses ke2791
# Spectogram sukses ke2792
# Spectogram sukses ke2793
# Spectogram sukses ke2794
# Spectogram sukses ke2795
# Spectogram sukses ke2796
# Spectogram sukses ke2797
# Spectogram sukses ke2798
# Spectogram sukses ke2799
# Spectogram sukses ke2800
# Spectogram sukses ke2801
# Spectogram sukses ke2802
# Spectogram sukses ke2803
# Spectogram gagal ke2126
# Spectogram sukses ke2804
# Spectogram sukses ke2805
# Spectogram sukses ke2806
# Spectogram sukses ke2807
# Spectogram sukses ke2808
# Spectogram sukses ke2809
# Spectogram sukses ke2810
# Spectogram sukses ke2811
# Spectogram sukses ke2812
# Spectogram sukses ke2813
# Spectogram sukses ke2814
# Spectogram sukses ke2815
# Spectogram sukses ke2816
# Spectogram sukses ke2817
# Spectogram sukses ke2818
# Spectogram sukses ke2819
# Spectogram sukses ke2820
# Spectogram sukses ke2821
# Spectogram sukses ke2822
# Spectogram sukses ke2823
# Spectogram sukses ke2824
# Spectogram sukses ke2825
# Spectogram sukses ke2826
# Spectogram sukses ke2827
# Spectogram sukses ke2828
# Spectogram sukses ke2829
# Spectogram sukses ke2830
# Spectogram sukses ke2831
# Spectogram sukses ke2832
# Spectogram sukses ke2833
# Spectogram sukses ke2834
# Spectogram sukses ke2835
# Spectogram gagal ke2127
# Spectogram sukses ke2836
# Spectogram sukses ke2837
# Spectogram sukses ke2838
# Spectogram sukses ke2839
# Spectogram sukses ke2840
# Spectogram sukses ke2841
# Spectogram sukses ke2842
# Spectogram sukses ke2843
# Spectogram gagal ke2128
# Spectogram sukses ke2844
# Spectogram sukses ke2845
# Spectogram sukses ke2846
# Spectogram sukses ke2847
# Spectogram sukses ke2848
# Spectogram sukses ke2849
# Spectogram gagal ke2129
# Spectogram sukses ke2850
# Spectogram sukses ke2851
# Spectogram sukses ke2852
# Spectogram sukses ke2853
# Spectogram sukses ke2854
# Spectogram sukses ke2855
# Spectogram sukses ke2856
# Spectogram sukses ke2857
# Spectogram sukses ke2858
# Spectogram sukses ke2859
# Spectogram gagal ke2130
# Spectogram sukses ke2860
# Spectogram sukses ke2861
# Spectogram sukses ke2862
# Spectogram sukses ke2863
# Spectogram sukses ke2864
# Spectogram gagal ke2131
# Spectogram sukses ke2865
# Spectogram sukses ke2866
# Spectogram sukses ke2867
# Spectogram sukses ke2868
# Spectogram sukses ke2869
# Spectogram sukses ke2870
# Spectogram sukses ke2871
# Spectogram sukses ke2872
# Spectogram sukses ke2873
# Spectogram gagal ke2132
# Spectogram sukses ke2874
# Spectogram sukses ke2875
# Spectogram sukses ke2876
# Spectogram sukses ke2877
# Spectogram sukses ke2878
# Spectogram sukses ke2879
# Spectogram gagal ke2133
# Spectogram sukses ke2880
# Spectogram sukses ke2881
# Spectogram sukses ke2882
# Spectogram sukses ke2883
# Spectogram sukses ke2884
# Spectogram gagal ke2134
# Spectogram sukses ke2885
# Spectogram sukses ke2886
# Spectogram sukses ke2887
# Spectogram sukses ke2888
# Spectogram sukses ke2889
# Spectogram sukses ke2890
# Spectogram sukses ke2891
# Spectogram sukses ke2892
# Spectogram sukses ke2893
# Spectogram sukses ke2894
# Spectogram gagal ke2135
# Spectogram sukses ke2895
# Spectogram sukses ke2896
# Spectogram sukses ke2897
# Spectogram sukses ke2898
# Spectogram sukses ke2899
# Spectogram sukses ke2900
# Spectogram sukses ke2901
# Spectogram gagal ke2136
# Spectogram sukses ke2902
# Spectogram sukses ke2903
# Spectogram sukses ke2904
# Spectogram gagal ke2137
# Spectogram sukses ke2905
# Spectogram sukses ke2906
# Spectogram sukses ke2907
# Spectogram sukses ke2908
# Spectogram sukses ke2909
# Spectogram sukses ke2910
# Spectogram sukses ke2911
# Spectogram sukses ke2912
# Spectogram sukses ke2913
# Spectogram sukses ke2914
# Spectogram sukses ke2915
# Spectogram sukses ke2916
# Spectogram sukses ke2917
# Spectogram sukses ke2918
# Spectogram sukses ke2919
# Spectogram sukses ke2920
# Spectogram sukses ke2921
# Spectogram sukses ke2922
# Spectogram sukses ke2923
# Spectogram gagal ke2138
# Spectogram sukses ke2924
# Spectogram sukses ke2925
# Spectogram sukses ke2926
# Spectogram sukses ke2927
# Spectogram sukses ke2928
# Spectogram sukses ke2929
# Spectogram sukses ke2930
# Spectogram sukses ke2931
# Spectogram sukses ke2932
# Spectogram sukses ke2933
# Spectogram sukses ke2934
# Spectogram sukses ke2935
# Spectogram sukses ke2936
# Spectogram sukses ke2937
# Spectogram sukses ke2938
# Spectogram sukses ke2939
# Spectogram sukses ke2940
# Spectogram sukses ke2941
# Spectogram sukses ke2942
# Spectogram sukses ke2943
# Spectogram sukses ke2944
# Spectogram sukses ke2945
# Spectogram sukses ke2946
# Spectogram sukses ke2947
# Spectogram sukses ke2948
# Spectogram sukses ke2949
# Spectogram sukses ke2950
# Spectogram sukses ke2951
# Spectogram sukses ke2952
# Spectogram sukses ke2953
# Spectogram sukses ke2954
# Spectogram sukses ke2955
# Spectogram sukses ke2956
# Spectogram sukses ke2957
# Spectogram sukses ke2958
# Spectogram sukses ke2959
# Spectogram sukses ke2960
# Spectogram sukses ke2961
# Spectogram gagal ke2139
# Spectogram sukses ke2962
# Spectogram sukses ke2963
# Spectogram sukses ke2964
# Spectogram sukses ke2965
# Spectogram sukses ke2966
# Spectogram sukses ke2967
# Spectogram sukses ke2968
# Spectogram sukses ke2969
# Spectogram sukses ke2970
# Spectogram sukses ke2971
# Spectogram gagal ke2140
# Spectogram sukses ke2972
# Spectogram sukses ke2973
# Spectogram sukses ke2974
# Spectogram sukses ke2975
# Spectogram sukses ke2976
# Spectogram gagal ke2141
# Spectogram sukses ke2977
# Spectogram sukses ke2978
# Spectogram sukses ke2979
# Spectogram sukses ke2980
# Spectogram sukses ke2981
# Spectogram sukses ke2982
# Spectogram sukses ke2983
# Spectogram sukses ke2984
# Spectogram sukses ke2985
# Spectogram sukses ke2986
# Spectogram gagal ke2142
# Spectogram sukses ke2987
# Spectogram sukses ke2988
# Spectogram sukses ke2989
# Spectogram sukses ke2990
# Spectogram sukses ke2991
# Spectogram sukses ke2992
# Spectogram sukses ke2993
# Spectogram sukses ke2994
# Spectogram sukses ke2995
# Spectogram sukses ke2996
# Spectogram sukses ke2997
# Spectogram sukses ke2998
# Spectogram sukses ke2999
# Spectogram sukses ke3000
# Spectogram sukses ke3001
# Spectogram sukses ke3002
# Spectogram sukses ke3003
# Spectogram gagal ke2143
# Spectogram sukses ke3004
# Spectogram sukses ke3005
# Spectogram sukses ke3006
# Spectogram sukses ke3007
# Spectogram sukses ke3008
# Spectogram sukses ke3009
# Spectogram sukses ke3010
# Spectogram sukses ke3011
# Spectogram sukses ke3012
# Spectogram sukses ke3013
# Spectogram sukses ke3014
# Spectogram sukses ke3015
# Spectogram sukses ke3016
# Spectogram sukses ke3017
# Spectogram sukses ke3018
# Spectogram sukses ke3019
# Spectogram gagal ke2144
# Spectogram gagal ke2145
# Spectogram sukses ke3020
# Spectogram sukses ke3021
# Spectogram sukses ke3022
# Spectogram sukses ke3023
# Spectogram sukses ke3024
# Spectogram sukses ke3025
# Spectogram sukses ke3026
# Spectogram sukses ke3027
# Spectogram sukses ke3028
# Spectogram gagal ke2146
# Spectogram gagal ke2147
# Spectogram sukses ke3029
# Spectogram gagal ke2148
# Spectogram sukses ke3030
# Spectogram sukses ke3031
# Spectogram sukses ke3032
# Spectogram sukses ke3033
# Spectogram sukses ke3034
# Spectogram sukses ke3035
# Spectogram sukses ke3036
# Spectogram sukses ke3037
# Spectogram sukses ke3038
# Spectogram gagal ke2149
# Spectogram sukses ke3039
# Spectogram sukses ke3040
# Spectogram sukses ke3041
# Spectogram sukses ke3042
# Spectogram sukses ke3043
# Spectogram sukses ke3044
# Spectogram sukses ke3045
# Spectogram sukses ke3046
# Spectogram sukses ke3047
# Spectogram sukses ke3048
# Spectogram sukses ke3049
# Spectogram sukses ke3050
# Spectogram sukses ke3051
# Spectogram sukses ke3052
# Spectogram sukses ke3053
# Spectogram sukses ke3054
# Spectogram sukses ke3055
# Spectogram sukses ke3056
# Spectogram sukses ke3057
# Spectogram sukses ke3058
# Spectogram sukses ke3059
# Spectogram sukses ke3060
# Spectogram gagal ke2150
# Spectogram sukses ke3061
# Spectogram sukses ke3062
# Spectogram sukses ke3063
# Spectogram sukses ke3064
# Spectogram sukses ke3065
# Spectogram sukses ke3066
# Spectogram sukses ke3067
# Spectogram sukses ke3068
# Spectogram sukses ke3069
# Spectogram sukses ke3070
# Spectogram sukses ke3071
# Spectogram sukses ke3072
# Spectogram sukses ke3073
# Spectogram sukses ke3074
# Spectogram sukses ke3075
# Spectogram sukses ke3076
# Spectogram gagal ke2151
# Spectogram sukses ke3077
# Spectogram sukses ke3078
# Spectogram sukses ke3079
# Spectogram sukses ke3080
# Spectogram sukses ke3081
# Spectogram sukses ke3082
# Spectogram sukses ke3083
# Spectogram sukses ke3084
# Spectogram sukses ke3085
# Spectogram sukses ke3086
# Spectogram sukses ke3087
# Spectogram sukses ke3088
# Spectogram sukses ke3089
# Spectogram sukses ke3090
# Spectogram sukses ke3091
# Spectogram sukses ke3092
# Spectogram sukses ke3093
# Spectogram sukses ke3094
# Spectogram sukses ke3095
# Spectogram sukses ke3096
# Spectogram sukses ke3097
# Spectogram gagal ke2152
# Spectogram sukses ke3098
# Spectogram gagal ke2153
# Spectogram sukses ke3099
# Spectogram sukses ke3100
# Spectogram gagal ke2154
# Spectogram sukses ke3101
# Spectogram sukses ke3102
# Spectogram sukses ke3103
# Spectogram sukses ke3104
# Spectogram sukses ke3105
# Spectogram sukses ke3106
# Spectogram sukses ke3107
# Spectogram gagal ke2155
# Spectogram sukses ke3108
# Spectogram sukses ke3109
# Spectogram sukses ke3110
# Spectogram sukses ke3111
# Spectogram sukses ke3112
# Spectogram sukses ke3113
# Spectogram sukses ke3114
# Spectogram sukses ke3115
# Spectogram sukses ke3116
# Spectogram sukses ke3117
# Spectogram sukses ke3118
# Spectogram sukses ke3119
# Spectogram sukses ke3120
# Spectogram sukses ke3121
# Spectogram sukses ke3122
# Spectogram sukses ke3123
# Spectogram gagal ke2156
# Spectogram sukses ke3124
# Spectogram sukses ke3125
# Spectogram sukses ke3126
# Spectogram sukses ke3127
# Spectogram sukses ke3128
# Spectogram sukses ke3129
# Spectogram sukses ke3130
# Spectogram sukses ke3131
# Spectogram sukses ke3132
# Spectogram sukses ke3133
# Spectogram sukses ke3134
# Spectogram sukses ke3135
# Spectogram sukses ke3136
# Spectogram sukses ke3137
# Spectogram gagal ke2157
# Spectogram sukses ke3138
# Spectogram sukses ke3139
# Spectogram sukses ke3140
# Spectogram sukses ke3141
# Spectogram sukses ke3142
# Spectogram sukses ke3143
# Spectogram sukses ke3144
# Spectogram sukses ke3145
# Spectogram gagal ke2158
# Spectogram sukses ke3146
# Spectogram sukses ke3147
# Spectogram gagal ke2159
# Spectogram sukses ke3148
# Spectogram sukses ke3149
# Spectogram sukses ke3150
# Spectogram gagal ke2160
# Spectogram sukses ke3151
# Spectogram sukses ke3152
# Spectogram sukses ke3153
# Spectogram sukses ke3154
# Spectogram sukses ke3155
# Spectogram sukses ke3156
# Spectogram sukses ke3157
# Spectogram sukses ke3158
# Spectogram sukses ke3159
# Spectogram sukses ke3160
# Spectogram sukses ke3161
# Spectogram sukses ke3162
# Spectogram sukses ke3163
# Spectogram sukses ke3164
# Spectogram sukses ke3165
# Spectogram sukses ke3166
# Spectogram sukses ke3167
# Spectogram sukses ke3168
# Spectogram gagal ke2161
# Spectogram sukses ke3169
# Spectogram sukses ke3170
# Spectogram sukses ke3171
# Spectogram sukses ke3172
# Spectogram sukses ke3173
# Spectogram sukses ke3174
# Spectogram sukses ke3175
# Spectogram sukses ke3176
# Spectogram sukses ke3177
# Spectogram sukses ke3178
# Spectogram sukses ke3179
# Spectogram sukses ke3180
# Spectogram gagal ke2162
# Spectogram sukses ke3181
# Spectogram sukses ke3182
# Spectogram sukses ke3183
# Spectogram sukses ke3184
# Spectogram sukses ke3185
# Spectogram sukses ke3186
# Spectogram sukses ke3187
# Spectogram sukses ke3188
# Spectogram sukses ke3189
# Spectogram sukses ke3190
# Spectogram sukses ke3191
# Spectogram sukses ke3192
# Spectogram sukses ke3193
# Spectogram sukses ke3194
# Spectogram sukses ke3195
# Spectogram sukses ke3196
# Spectogram sukses ke3197
# Spectogram sukses ke3198
# Spectogram sukses ke3199
# Spectogram gagal ke2163
# Spectogram sukses ke3200
# Spectogram sukses ke3201
# Spectogram sukses ke3202
# Spectogram sukses ke3203
# Spectogram sukses ke3204
# Spectogram sukses ke3205
# Spectogram sukses ke3206
# Spectogram sukses ke3207
# Spectogram sukses ke3208
# Spectogram sukses ke3209
# Spectogram sukses ke3210
# Spectogram sukses ke3211
# Spectogram sukses ke3212
# Spectogram sukses ke3213
# Spectogram sukses ke3214
# Spectogram sukses ke3215
# Spectogram sukses ke3216
# Spectogram sukses ke3217
# Spectogram sukses ke3218
# Spectogram sukses ke3219
# Spectogram sukses ke3220
# Spectogram sukses ke3221
# Spectogram sukses ke3222
# Spectogram sukses ke3223
# Spectogram sukses ke3224
# Spectogram sukses ke3225
# Spectogram sukses ke3226
# Spectogram sukses ke3227
# Spectogram sukses ke3228
# Spectogram sukses ke3229
# Spectogram sukses ke3230
# Spectogram sukses ke3231
# Spectogram sukses ke3232
# Spectogram sukses ke3233
# Spectogram sukses ke3234
# Spectogram sukses ke3235
# Spectogram sukses ke3236
# Spectogram gagal ke2164
# Spectogram sukses ke3237
# Spectogram sukses ke3238
# Spectogram sukses ke3239
# Spectogram sukses ke3240
# Spectogram sukses ke3241
# Spectogram gagal ke2165

# %%
cwd = os.getcwd()
os.chdir(f'./')
print(cwd)
destination_folder_depression = f"./Depressionvsnormal_spectogram//Depression"
destination_folder_normal = f".//Depressionvsnormal_spectogram//Normal"

# os.listdir returns a list containing all files under the given path
print(f"There are {len(os.listdir( destination_folder_depression))} images of Depression.")
print(f"There are {len(os.listdir(destination_folder_normal))} images of Normal.")

# %%
# Define root directory
#make runningan folder
induk = ".//runningan"
try:
    os.mkdir(induk)
except:
    print("its exist")
    
root_dir = f'{induk}\\depressionvsnormal\\'
#make depressionvsnormal folder
try:
    os.mkdir(root_dir)
except:
    print("its exist")

# Empty directory to prevent FileExistsError is the function is run several times
if os.path.exists(root_dir):
  shutil.rmtree(root_dir)

# GRADED FUNCTION: create_train_test_dirs
def create_train_test_dirs(root_path):
  ### START CODE HERE

  # HINT:
  # Use os.makedirs to create your directories with intermediate subdirectories
  # Don't hardcode the paths. Use os.path.join to append the new directories to the root_path parameter
  os.makedirs(os.path.join(root_path, "training/"))
  os.makedirs(os.path.join(root_path, "testing/"))
  os.makedirs(os.path.join(root_path, "training/Depression/"))
  os.makedirs(os.path.join(root_path, "testing/Depression/"))
  os.makedirs(os.path.join(root_path, "training/Normal/"))
  os.makedirs(os.path.join(root_path, "testing/Normal/"))
  pass
  
  ### END CODE HERE

  
try:
  create_train_test_dirs(root_path=root_dir)
except FileExistsError:
  print("You should not be seeing this since the upper directory is removed beforehand")

# %%
# Test your create_train_test_dirs function

for rootdir, dirs, files in os.walk(root_dir):
    for subdir in dirs:
        print(os.path.join(rootdir, subdir))

# %%
# GRADED FUNCTION: split_data
from shutil import copyfile
def split_data(SOURCE, TRAINING, TESTING, SPLIT_SIZE):

  ### START CODE HERE
  file_dipakai = []
  for file in os.listdir(SOURCE):
    full_file_address= SOURCE + file
    if os.path.getsize(full_file_address)>0:
      file_dipakai.append(file)
    else:
      print(f"{file} is zero length, so ignoring.")
  
  jumlah_training = int(int(len(file_dipakai))*SPLIT_SIZE)
  jumlah_testing = int(int(len(file_dipakai)-jumlah_training))
  file_dipakai_sudah_random = random.sample(file_dipakai, len(file_dipakai))
  files_training = file_dipakai_sudah_random[0:jumlah_training]
  files_testing = file_dipakai_sudah_random[-jumlah_testing:]

  for file_training in files_training:
    try:
      file = SOURCE + file_training
      tempat_copy= TRAINING + file_training
      copyfile(file, tempat_copy)
    except:
      pass
  for file_testing in files_testing:
    try:
      file = SOURCE + file_testing
      tempat_copy= TESTING + file_testing
      copyfile(file, tempat_copy)
    except:
      pass

# %%
cwd = os.getcwd()
print(cwd)
TRAINING_DIR = ".\\runningan\\depressionvsnormal\\training\\"
TESTING_DIR = ".\\runningan\\depressionvsnormal\\testing\\"

# Define paths
DEPRESSION_SOURCE_DIR = ".\\Depressionvsnormal_spectogram\\Depression\\"
TRAINING_DEPRESSIONS_DIR = os.path.join(TRAINING_DIR, "Depression\\")
TESTING_DEPRESSIONS_DIR = os.path.join(TESTING_DIR, "Depression\\")

NORMAL_SOURCE_DIR = ".\\Depressionvsnormal_spectogram\\Normal\\"
TRAINING_NORMAL_DIR = os.path.join(TRAINING_DIR, "Normal\\")
TESTING_NORMAL_DIR = os.path.join(TESTING_DIR, "Normal\\")

# %%
cwd = os.getcwd()
print(cwd)
if len(os.listdir(TRAINING_DEPRESSIONS_DIR)) > 0:
  for file in os.scandir(TRAINING_DEPRESSIONS_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_DEPRESSIONS_DIR)) > 0:
  for file in os.scandir(TESTING_DEPRESSIONS_DIR):
    os.remove(file.path)
if len(os.listdir(TRAINING_NORMAL_DIR)) > 0:
  for file in os.scandir(TRAINING_NORMAL_DIR):
    os.remove(file.path)
if len(os.listdir(TESTING_NORMAL_DIR)) > 0:
  for file in os.scandir(TESTING_NORMAL_DIR):
    os.remove(file.path)

# Define proportion of images used for training
split_size = .9

# Run the function
# NOTE: Messages about zero length images should be printed out
split_data(DEPRESSION_SOURCE_DIR, TRAINING_DEPRESSIONS_DIR, TESTING_DEPRESSIONS_DIR, split_size)
split_data(NORMAL_SOURCE_DIR, TRAINING_NORMAL_DIR, TESTING_NORMAL_DIR, split_size)

# Check that the number of images matches the expected output
print(f"There are {len(os.listdir(TRAINING_DEPRESSIONS_DIR))} images of depression for training")
print(f"There are {len(os.listdir(TESTING_DEPRESSIONS_DIR))} images of depression for testing")
print(f"There are {len(os.listdir(TRAINING_NORMAL_DIR))} images of normal for training")
print(f"There are {len(os.listdir(TESTING_NORMAL_DIR))} images of normal for testing")

# %%
def train_val_generators(TRAINING_DIR, VALIDATION_DIR):

  # Instantiate the ImageDataGenerator class (don't forget to set the rescale argument)
  train_datagen = ImageDataGenerator(rescale=1.0/255.)

  # Pass in the appropiate arguments to the flow_from_directory method
  train_generator = train_datagen.flow_from_directory(directory=TRAINING_DIR,
                                                      batch_size=10,
                                                      class_mode='binary',
                                                      color_mode = 'rgb',
                                                      shuffle=True,
                                                      seed=42,
                                                      target_size=(512, 512))

                                                           
     

  # Instantiate the ImageDataGenerator class (don't forget to set the rescale argument)
  validation_datagen = ImageDataGenerator(rescale=1.0/255.)

  # Pass in the appropiate arguments to the flow_from_directory method
  validation_generator = validation_datagen.flow_from_directory(directory=VALIDATION_DIR,
                                                      batch_size=10,
                                                      class_mode='binary',
                                                      color_mode = 'rgb',
                                                      shuffle=True,
                                                      seed=42,
                                                      target_size=(512, 512))
  
  ### END CODE HERE
  return train_generator, validation_generator

# %%
train_generator, validation_generator = train_val_generators(TRAINING_DIR, TESTING_DIR)

# %%
import pathlib
import numpy as np

data_dir = pathlib.Path(TESTING_DIR)
commands = np.array(tf.io.gfile.listdir(str(data_dir)))
num_labels = len(commands)
print('Commands:', commands)

filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')
filenames = tf.random.shuffle(filenames)
num_samples = len(filenames)
print('Number of total examples:', num_samples)
print('Number of examples per label:',
      len(tf.io.gfile.listdir(str(data_dir / commands[0]))))
print('Example file tensor:', filenames[0])

# %%
def create_model():
  model = tf.keras.models.Sequential([ 
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255, input_shape=(512,512,3)),
  tf.keras.layers.Conv2D(4, 2, strides=(1, 1),padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=(2, 2),),
  tf.keras.layers.Conv2D(8, 3, strides=(1, 1),padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=(2, 2),),
  tf.keras.layers.Conv2D(16, 4, strides=(1, 1),padding='same', activation='relu'),
  tf.keras.layers.MaxPooling2D(pool_size=(2, 2),strides=(2, 2),),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_labels, activation='sigmoid'),
  ])
  
  opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
  model.compile(
    optimizer=opt,
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy'],)
    
  return model

# %%
model = create_model()
model.summary()

# Train the model
# Note that this may take some time.
EPOCHS = 1
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=EPOCHS,
    verbose=1,
)

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.show()
print("")

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")
plt.show()

# %%
saved_model_path = "E:\\Capstone_Project\\h5_running\\predictive_model_v_8.h5"
#model.save(saved_model_path)

# %%
##### Batas penggunaan model yang sudah jadi #############

# %%
def get_spectrogram_and_label_id(audio_file, label):
    spectrogram = audio_file
    spectrogram = tf.expand_dims(spectrogram, -1)
    label_id = tf.argmax(label == commands)
    return spectrogram, label_id

def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2]

def get_waveform_and_label(file_path):
    label = get_label(file_path)
    audio_binary = tf.io.read_file(file_path)
    waveform = file_path
    return waveform, label

def preprocess_dataset(files):
    files_ds = tf.data.Dataset.from_tensor_slices(files)
    output_ds = files_ds.map(get_waveform_and_label, num_parallel_calls=AUTOTUNE)
    output_ds = output_ds.map(
        get_spectrogram_and_label_id, num_parallel_calls=AUTOTUNE)
    return output_ds

def transformator(file_gambar_spectogram):
    IMG_PATH = file_gambar_spectogram
    image = cv2.imread(IMG_PATH)
    image = cv2.resize(image, (512, 512))
    image = image.astype("float") / 255.0
    image = img_to_array(image)
    image = np.expand_dims(image, axis=0)
    return image

def identifikasi_gambar(gambar):
    y_pred = np.argmax(model.predict(transformator(gambar)), axis=1)
    if str(y_pred[0]) == "0":
       label_nama = "Depresi"
    elif str(y_pred[0]) == "1":
       label_nama = "Normal"
    return label_nama

def transform_audio_to_spectogram_to_testing(audio_file):
    y, sr = librosa.load(audio_file)
    librosa.feature.melspectrogram(y=y, sr=sr)
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128,
                                               fmax=8000)
    fig, ax = plt.subplots()
    S_dB = librosa.power_to_db(S, ref=np.max)
    img = librosa.display.specshow(S_dB)
            # ax.set(title='Log Mel-frequency spectrogram')
    folder_dituju = "E:\Capstone_Project\\runningan\jalur_lewat_testing"
    savefigure = os.path.join(folder_dituju, 'jalur_lewat.jpg')
    plt.savefig(savefigure)
    status = identifikasi_gambar(savefigure)
    return status

AUTOTUNE = tf.data.AUTOTUNE
test_files = filenames
test_ds = preprocess_dataset(test_files)

test_audio = []
test_labels = []
for audio, label in test_ds.as_numpy_iterator():
    test_audio.append(str(audio[0].decode("utf-8")))
    test_labels.append(label)

# Normal [1] , Depresi [0]

# %%
model = models.load_model(saved_model_path)

# %%
benar = 0
salah = 0
for i in range(8):
    y_pred = np.argmax(model.predict(transformator(test_audio[i])), axis=1)
    y_true = test_labels[i]
    if str(y_pred[0]) == str(y_true):
       benar+=1
    else:
       salah+=1
keakuratan = benar/(benar+salah) *100
print("keakuratan {} %".format(keakuratan))
#memprediksi testing 79.125% benar untuk keseluruhan training

# %%
cwd = os.getcwd()
print(cwd)
Benar = 0
Salah = 0

for i in range(10):
    try:
        gambar = ".\\runningan\\depressionvsnormal\\testing\\Normal\\Normal{}.jpg".format(i)
        resp = identifikasi_gambar(gambar)
        if resp == "Depresi":
            Benar+=1
        else:
            Salah+=1
    except:
        print("")
        
totalpersen = Benar / (Benar+Salah)*100
print(Benar)
print(Salah)
print(totalpersen)
#memprediksi testing 63% benar untuk cek depresi untuk  keseluruhan testin

# %%
Benar = 0
Salah = 0
for i in range(10):
    try:
        gambar = ".\\runningan\\depressionvsnormal\\testing\\Normal\\Normal{}.jpg".format(i)
        resp = identifikasi_gambar(gambar)
        if resp == "Normal":
            Benar+=1
        else:
            Salah+=1
    except:
        print("")
        
totalpersen = Benar / (Benar+Salah)*100
print(Benar)
print(Salah)
print(totalpersen)
#memprediksi testing 89% benar untuk cek normal untuk keseluruhan testing

# %%
audio_file = ".\Depressionvsnormal\Depression\Depression4.wav"
hasil = transform_audio_to_spectogram_to_testing(audio_file)

print(hasil)

# %%
from flask import Flask
from gevent.pywsgi import WSGIServer

app = Flask(__name__)
@app.route('/predict', methods=['POST'])
def infer_image():
    if request.method == 'POST':
        if 'file' not in request.files:
            return "Masukan hanya jenis file saja"
        file = request.files.get('file')
        try:
            img = transform_audio_to_spectogram_to_testing(file)
            img_respon =  { "status_user":img,"status_running":"Sukses"}
        except:
            img_respon =  { "status_user":"-","status_running":"Gagal"}
        return img_respon
    
@app.route('/', methods=['GET'])
def index():
    return "Selamat datang dimachine learning kami"

if __name__ == '__main__':
    # Debug/Development
    # app.run(debug=True, host="0.0.0.0", port="5000")
    # Production
    http_server = WSGIServer(('127.0.0.1', 5000), app)
    http_server.serve_forever()
